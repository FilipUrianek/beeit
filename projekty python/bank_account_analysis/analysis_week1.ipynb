# %% [markdown]
# <h1> Moduly pro datovou analýzu </h1>
#
# <p> Abychom mohli data v jazyce python analyzovat a provádět výpočty rychle a výpočetně efektivně, je zapotřebí nainstalovat a importovat několik klíčových modulů do našeho Jupyter notebooku</p>
#
#
# <h5>Výpočet statistik, funkcí a matematických operací s vysokým výkonem:</h5>
# Numpy
#
# <https://numpy.org/doc/stable>
#
# <h5>Tvorba, načítání a úprava dat v tabulkových formátech:</h5>
# Pandas
#
# <https://pandas.pydata.org/docs/>
#
# <h5>Vizualizace dat a tvorba grafů:</h5>
#
# Matplotlib (nejpopulárnější)
# <https://matplotlib.org/>
# <br>
#
# Plotly (verzatilnější):
# <br>
#
# Plotly Express (jednodušší grafy)
# <https://plotly.com/python-api-reference/plotly.express.html>
# <br>
#
# Plotly Graph Objects (složitější ale flexibilnější grafy a vizualizace)
# <https://plotly.com/python-api-reference/plotly.graph_objects.html>
# <br>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go 
import plotly.express as px
import os

# %% [markdown]
# <h5>Prvním krokem bude tvorba datové struktury, tzv. Dataframu, který knihovna pandas využívá pro reprezentaci tabulkových dat</h5>
#
# Dataframe lze vytvořit několika způsoby, nejčastěji z Python dictionary, načtením CSV souboru či Excelové tabulky (.xls, .xslx). Podporované jsou například i SQL databáze.
#
# Více o dataframu: <https://pandas.pydata.org/docs/reference/frame.html>
#
# Více o I/O modulu pandas (načítání a ukládání souborů): <https://pandas.pydata.org/docs/reference/io.html>

# %%
my_dict = {
   "days":["monday","tuesday","wednesday","thursday","friday","saturday","sunday"],
   "hours_worked":[8,9,11,7,6,2,0]
}

df_dict = pd.DataFrame.from_dict(my_dict)
df_dict
# Out:
#         days  hours_worked
# 0     monday             8
# 1    tuesday             9
# 2  wednesday            11
# 3   thursday             7
# 4     friday             6
# 5   saturday             2
# 6     sunday             0

# %%
df_csv = pd.read_csv("dataset/sample.csv", usecols=["days","hours_worked"])
df_csv
# Out:
#         days  hours_worked
# 0     monday             8
# 1    tuesday             9
# 2  wednesday            11
# 3   thursday             7
# 4     friday             6
# 5   saturday             2
# 6     sunday             0

# %%
df_excel = pd.read_excel("dataset/sample.xlsx",
                         usecols=["days", "hours_worked"])
df_excel
# Out:
#         days  hours_worked
# 0     monday             8
# 1    tuesday             9
# 2  wednesday            11
# 3   thursday             7
# 4     friday             6
# 5   saturday             2
# 6     sunday             0

# %% [markdown]
# <h5>Cíl projektu</h5>
#
# Cílem práce je pomocí modulu Pandas načíst a upravit výpis pohybů na účtu z internetového bankovnictví, výpočítat statistiky pomocí modulu Numpy a vizualizovat data pomocí modulů Matplotlib a Plotly <br>
#
# Ve složce `dataset` se za tímto účelem nacházejí soubory `csob.xls` a `sporitelna.csv`

# %%
df_csob = pd.read_excel(os.path.join("dataset", "csob.xls"))
df_csob
# Out:
#        account no. date of posting   amount currency    deposit  \
# 0   284622580/0300      2022-07-19  -791.15      CZK   88782.78
# 1   284622580/0300      2022-07-19   -45.00      CZK   89573.93
# 2   284622580/0300      2022-07-18  -475.93      CZK   89618.93
# 3   284622580/0300      2022-07-18  -225.44      CZK   90094.86
# 4   284622580/0300      2022-07-18 -2335.24      CZK   90320.30
# ..             ...             ...      ...      ...        ...
# 74  284622580/0300      2022-06-20  -689.99      CZK  162730.48
# 75  284622580/0300      2022-06-20  -290.52      CZK  163420.47
# 76  284622580/0300      2022-06-20  -189.92      CZK  163710.99
# 77  284622580/0300      2022-06-20   -68.85      CZK  163900.91
# 78  284622580/0300      2022-06-20 -1044.56      CZK  163969.76
#
#     counter-account number  counter-account bank number  \
# 0                      NaN                          NaN
# 1             2.008200e+09                       5500.0
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# ..                     ...                          ...
# 74                     NaN                          NaN
# 75                     NaN                          NaN
# 76                     NaN                          NaN
# 77                     NaN                          NaN
# 78                     NaN                          NaN
#
#    name of counter-account  constant symbol  variable symbol  specific symbol  \
# 0                      NaN           1178.0      405000199.0     2.212104e+09
# 1                      NaN              NaN              NaN              NaN
# 2                      NaN           1178.0      405000198.0     2.212104e+09
# 3                      NaN           1178.0      405000197.0     2.212104e+09
# 4                      NaN           1178.0      405000197.0     2.212104e+09
# ..                     ...              ...              ...              ...
# 74                     NaN           1178.0      405000170.0     2.212104e+09
# 75                     NaN           1178.0      405000170.0     2.212104e+09
# 76                     NaN           1178.0      405000169.0     2.212104e+09
# 77                     NaN           1178.0      405000169.0     2.212104e+09
# 78                     NaN           1178.0      405000169.0     2.212104e+09
#
#        marking the operation  Transaction ID  \
# 0     Debit card transaction     10479404244
# 1   Outgoing instant payment     10478823066
# 2     Debit card transaction     10476817120
# 3     Debit card transaction     10476525982
# 4     Debit card transaction     10476525984
# ..                       ...             ...
# 74    Debit card transaction     10400956338
# 75    Debit card transaction     10400956344
# 76    Debit card transaction     10400813269
# 77    Debit card transaction     10400813274
# 78    Debit card transaction     10400813278
#
#                                                  note
# 0   Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...
# 1                                             Spotify
# 2   Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...
# 3   Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...
# 4   Amount: 92 CHF 14.07.2022, Place: Restaurant H...
# ..                                                ...
# 74  Amount: 285 NOK 17.06.2022, Place: VULKANFISK ...
# 75  Amount: 120 NOK 17.06.2022, Place: ONEPARK VUL...
# 76  Amount: 80 SEK 16.06.2022, Place: CAFEVA AB, B...
# 77  Amount: 29 SEK 16.06.2022, Place: KAWAII.SE GB...
# 78  Amount: 440 SEK 16.06.2022, Place: STROMMA PC ...
#
# [79 rows x 14 columns]

# %%
df_sporitelna = pd.read_csv(os.path.join("dataset", "sporitelna.csv"),
                            delimiter=';', decimal=",")
df_sporitelna
# Out:
#    Cislo uctu vlastnika Datum zauctovani  \
# 0       1914236073/0800       26.08.2022
# 1       1914236073/0800       25.08.2022
# 2       1914236073/0800       25.08.2022
# 3       1914236073/0800       24.08.2022
# 4       1914236073/0800       24.08.2022
# 5       1914236073/0800       24.08.2022
# 6       1914236073/0800       23.08.2022
# 7       1914236073/0800       22.08.2022
# 8       1914236073/0800       21.08.2022
# 9       1914236073/0800       21.08.2022
# 10      1914236073/0800       20.08.2022
# 11      1914236073/0800       19.08.2022
# 12      1914236073/0800       19.08.2022
# 13      1914236073/0800       19.08.2022
# 14      1914236073/0800       19.08.2022
# 15      1914236073/0800       19.08.2022
# 16      1914236073/0800       18.08.2022
# 17      1914236073/0800       18.08.2022
# 18      1914236073/0800       18.08.2022
# 19      1914236073/0800       17.08.2022
# 20      1914236073/0800       17.08.2022
# 21      1914236073/0800       17.08.2022
# 22      1914236073/0800       17.08.2022
# 23      1914236073/0800       14.08.2022
# 24      1914236073/0800       14.08.2022
# 25      1914236073/0800       14.08.2022
# 26      1914236073/0800       14.08.2022
# 27      1914236073/0800       13.08.2022
# 28      1914236073/0800       12.08.2022
# 29      1914236073/0800       11.08.2022
# 30      1914236073/0800       10.08.2022
# 31      1914236073/0800       10.08.2022
# 32      1914236073/0800       10.08.2022
# 33      1914236073/0800       09.08.2022
# 34      1914236073/0800       08.08.2022
# 35      1914236073/0800       07.08.2022
# 36      1914236073/0800       06.08.2022
# 37      1914236073/0800       06.08.2022
# 38      1914236073/0800       05.08.2022
# 39      1914236073/0800       05.08.2022
# 40      1914236073/0800       04.08.2022
# 41      1914236073/0800       04.08.2022
# 42      1914236073/0800       04.08.2022
# 43      1914236073/0800       04.08.2022
# 44      1914236073/0800       04.08.2022
# 45      1914236073/0800       03.08.2022
# 46      1914236073/0800       01.08.2022
#
#                               Název protiuctu                      IBAN  \
# 0                            MPLA.CZ PRAHA CZ                       NaN
# 1                            MPLA.CZ PRAHA CZ                       NaN
# 2                            MPLA.CZ PRAHA CZ                       NaN
# 3                                         NaN                       NaN
# 4                            MPLA.CZ PRAHA CZ                       NaN
# 5              POTRAVINY PRAMEN LITOMERICE CZ                       NaN
# 6                                         NaN                       NaN
# 7                                         NaN                       NaN
# 8                                         NaN                       NaN
# 9   dm drogerie markt s.r.o. Ceske Budejov CZ                       NaN
# 10                                        NaN                       NaN
# 11                          KNOBOVA DOBROMILA  CZ4303000000000007137253
# 12                                        NaN                       NaN
# 13      ONO ROUDNICE NAD LABE ROUDNICE NAD CZ                       NaN
# 14                           MPLA.CZ PRAHA CZ                       NaN
# 15                           MPLA.CZ PRAHA CZ                       NaN
# 16                           MPLA.CZ PRAHA CZ                       NaN
# 17                           MPLA.CZ PRAHA CZ                       NaN
# 18                    PEKARSTVI LITOMERICE CZ                       NaN
# 19      MODRE ZAHRADNICTVI S.R. LITOMERICE CZ                       NaN
# 20                           MPLA.CZ PRAHA CZ                       NaN
# 21        LEKARNA NAD KAPLICKOU LITOMERICE CZ                       NaN
# 22                     DROGERIE LITOMERICE CZ                       NaN
# 23                           generaliceska.cz                       NaN
# 24                           MPLA.CZ PRAHA CZ                       NaN
# 25                 KOSIK.CZ S.R.O. Praha 4 CZ                       NaN
# 26                 KOSIK.CZ S.R.O. Praha 4 CZ                       NaN
# 27             POTRAVINY PRAMEN LITOMERICE CZ                       NaN
# 28                           MPLA.CZ PRAHA CZ                       NaN
# 29                           MPLA.CZ PRAHA CZ                       NaN
# 30                                        NaN                       NaN
# 31                           MPLA.CZ PRAHA CZ                       NaN
# 32                                        NaN                       NaN
# 33             KAUFLAND CZ 1110 LITOMERICE CZ                       NaN
# 34            RABBIT LITOMERICE LITOMERICE CZ                       NaN
# 35             Penny Litomerice Litomerice CZ                       NaN
# 36                           MPLA.CZ PRAHA CZ                       NaN
# 37            PPL CZ S.R.O. - D04 KRUPKA 1 CZ                       NaN
# 38                           MPLA.CZ PRAHA CZ                       NaN
# 39                                        NaN                       NaN
# 40                                    S-Power                       NaN
# 41                                        NaN                       NaN
# 42                           MPLA.CZ PRAHA CZ                       NaN
# 43                           MPLA.CZ PRAHA CZ                       NaN
# 44                                        NaN                       NaN
# 45                           MPLA.CZ PRAHA CZ                       NaN
# 46             DEKUJEME, ROHLIK.CZ Praha 8 CZ                       NaN
#
#          BIC           Protiucet  Bankovni kod protiuctu     Castka Mena
# 0        NaN                 NaN                     0.0     -80.00  CZK
# 1        NaN                 NaN                     0.0    -140.00  CZK
# 2        NaN                 NaN                     0.0     -80.00  CZK
# 3        NaN                 NaN                     NaN   -1000.00  CZK
# 4        NaN                 NaN                     0.0     -20.00  CZK
# 5        NaN                 NaN                     0.0    -241.69  CZK
# 6        NaN                 NaN                     NaN   -1800.00  CZK
# 7   CEKOCZPP        7137253/0300                   300.0    2000.00  CZK
# 8        NaN                 NaN                     NaN   -1000.00  CZK
# 9        NaN                 NaN                     0.0   -1598.00  CZK
# 10  GIBACZPX  35-2001269369/0800                   800.0    -300.00  CZK
# 11  CEKOCZPP        7137253/0300                   300.0    1000.00  CZK
# 12  KOMBCZPP       61447471/0100                   100.0    5000.00  CZK
# 13       NaN                 NaN                     0.0   -1643.30  CZK
# 14       NaN                 NaN                     0.0    -125.00  CZK
# 15       NaN                 NaN                     0.0     -80.00  CZK
# 16       NaN                 NaN                     0.0    -129.00  CZK
# 17       NaN                 NaN                     0.0     -30.00  CZK
# 18       NaN                 NaN                     0.0    -157.00  CZK
# 19       NaN                 NaN                     0.0    -235.00  CZK
# 20       NaN                 NaN                     0.0     -20.00  CZK
# 21       NaN                 NaN                     0.0    -258.00  CZK
# 22       NaN                 NaN                     0.0    -327.00  CZK
# 23  GIBACZPX        6705562/0800                   800.0   -2366.00  CZK
# 24       NaN                 NaN                     0.0     -20.00  CZK
# 25       NaN                 NaN                     0.0    -250.50  CZK
# 26       NaN                 NaN                     0.0   -1247.05  CZK
# 27       NaN                 NaN                     0.0    -251.60  CZK
# 28       NaN                 NaN                     0.0     -90.00  CZK
# 29       NaN                 NaN                     0.0    -113.00  CZK
# 30       NaN                 NaN                     NaN   -2800.00  CZK
# 31       NaN                 NaN                     0.0     -20.00  CZK
# 32  KOMBCZPP     3092910207/0100                   100.0    -300.00  CZK
# 33       NaN                 NaN                     0.0   -1498.83  CZK
# 34       NaN                 NaN                     0.0    -599.54  CZK
# 35       NaN                 NaN                     0.0    -507.16  CZK
# 36       NaN                 NaN                     0.0     -20.00  CZK
# 37       NaN                 NaN                     0.0    -497.00  CZK
# 38       NaN                 NaN                     0.0     -70.00  CZK
# 39  CNBACZPP     1112003411/0710                   710.0   -2187.00  CZK
# 40       NaN        7624422/0800                   800.0 -173500.00  CZK
# 41       NaN                 NaN                     NaN  175000.00  CZK
# 42       NaN                 NaN                     0.0     -30.00  CZK
# 43       NaN                 NaN                     0.0    -125.00  CZK
# 44  KOMBCZPP       61447471/0100                   100.0   16666.00  CZK
# 45       NaN                 NaN                     0.0     -20.00  CZK
# 46       NaN                 NaN                     0.0    -954.60  CZK

# %% [markdown]
# <h5>Základní informace o Dataframu</h5>

# %%
# souhrn informací

df_sporitelna.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Cislo uctu vlastnika    47 non-null     object
#  1   Datum zauctovani        47 non-null     object
#  2   Název protiuctu         36 non-null     object
#  3   IBAN                    1 non-null      object
#  4   BIC                     8 non-null      object
#  5   Protiucet               9 non-null      object
#  6   Bankovni kod protiuctu  42 non-null     float64
#  7   Castka                  47 non-null     float64
#  8   Mena                    47 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 3.4+ KB

# %%
# názvy všech neindexových sloupců

df_sporitelna.columns
# Out:
# Index(['Cislo uctu vlastnika', 'Datum zauctovani', 'Název protiuctu', 'IBAN',
#        'BIC', 'Protiucet', 'Bankovni kod protiuctu', 'Castka', 'Mena'],
#       dtype='object')

# %%
# index a jeho typ

df_sporitelna.index
# Out:
# RangeIndex(start=0, stop=47, step=1)

# %% [markdown]
# <h5>Změna indexu dataframu</h5>
#
# Častým požadavkem je změna indexu dataframu z výchozích čísel například na datum a čas či vlastní číslování

# %%
# změna indexu dataframu na cílovou hodnotu - v tomto případě přečíslujeme tak, aby dataframe začínal na řádku 1

df_csob["Index"] = [x+1 for x in range(len(df_csob))]
df_sporitelna["Index"] = [x + 1 for x in range(len(df_sporitelna))]

df_csob = df_csob.set_index("Index")
df_sporitelna = df_sporitelna.set_index("Index")

# %%
df_csob
# Out:
#           account no. date of posting   amount currency    deposit  \
# Index
# 1      284622580/0300      2022-07-19  -791.15      CZK   88782.78
# 2      284622580/0300      2022-07-19   -45.00      CZK   89573.93
# 3      284622580/0300      2022-07-18  -475.93      CZK   89618.93
# 4      284622580/0300      2022-07-18  -225.44      CZK   90094.86
# 5      284622580/0300      2022-07-18 -2335.24      CZK   90320.30
# ...               ...             ...      ...      ...        ...
# 75     284622580/0300      2022-06-20  -689.99      CZK  162730.48
# 76     284622580/0300      2022-06-20  -290.52      CZK  163420.47
# 77     284622580/0300      2022-06-20  -189.92      CZK  163710.99
# 78     284622580/0300      2022-06-20   -68.85      CZK  163900.91
# 79     284622580/0300      2022-06-20 -1044.56      CZK  163969.76
#
#        counter-account number  counter-account bank number  \
# Index
# 1                         NaN                          NaN
# 2                2.008200e+09                       5500.0
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# 5                         NaN                          NaN
# ...                       ...                          ...
# 75                        NaN                          NaN
# 76                        NaN                          NaN
# 77                        NaN                          NaN
# 78                        NaN                          NaN
# 79                        NaN                          NaN
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 1                         NaN           1178.0      405000199.0
# 2                         NaN              NaN              NaN
# 3                         NaN           1178.0      405000198.0
# 4                         NaN           1178.0      405000197.0
# 5                         NaN           1178.0      405000197.0
# ...                       ...              ...              ...
# 75                        NaN           1178.0      405000170.0
# 76                        NaN           1178.0      405000170.0
# 77                        NaN           1178.0      405000169.0
# 78                        NaN           1178.0      405000169.0
# 79                        NaN           1178.0      405000169.0
#
#        specific symbol     marking the operation  Transaction ID  \
# Index
# 1         2.212104e+09    Debit card transaction     10479404244
# 2                  NaN  Outgoing instant payment     10478823066
# 3         2.212104e+09    Debit card transaction     10476817120
# 4         2.212104e+09    Debit card transaction     10476525982
# 5         2.212104e+09    Debit card transaction     10476525984
# ...                ...                       ...             ...
# 75        2.212104e+09    Debit card transaction     10400956338
# 76        2.212104e+09    Debit card transaction     10400956344
# 77        2.212104e+09    Debit card transaction     10400813269
# 78        2.212104e+09    Debit card transaction     10400813274
# 79        2.212104e+09    Debit card transaction     10400813278
#
#                                                     note
# Index
# 1      Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...
# 2                                                Spotify
# 3      Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...
# 4      Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...
# 5      Amount: 92 CHF 14.07.2022, Place: Restaurant H...
# ...                                                  ...
# 75     Amount: 285 NOK 17.06.2022, Place: VULKANFISK ...
# 76     Amount: 120 NOK 17.06.2022, Place: ONEPARK VUL...
# 77     Amount: 80 SEK 16.06.2022, Place: CAFEVA AB, B...
# 78     Amount: 29 SEK 16.06.2022, Place: KAWAII.SE GB...
# 79     Amount: 440 SEK 16.06.2022, Place: STROMMA PC ...
#
# [79 rows x 14 columns]

# %% [markdown]
# <h5>Získávání částí dataframu podle názvů sloupců a indexů</h5>

# %%
# data pouze z jednoho sloupce

df_csob["amount"]
# Out:
# Index
# 1     -791.15
# 2      -45.00
# 3     -475.93
# 4     -225.44
# 5    -2335.24
#        ...
# 75    -689.99
# 76    -290.52
# 77    -189.92
# 78     -68.85
# 79   -1044.56
# Name: amount, Length: 79, dtype: float64

# %%
# výsledný formát dat je Pandas Series, můžeme indexovat pro získání konkrétní hodnoty

df_csob["amount"][1]
# Out:
# -791.15

# %%
# s daty můžeme dále pracovat, například vizualizovat v grafech - v tomto případě zůstatek na účtě 

px.line(y=df_csob["deposit"], x=df_csob["date of posting"], title="Zůstatek na účtě")

# %%
# získávání hodnot řádků na základě numerických indexů (pozor, index běží od 0 do len(df)-1)

df_sporitelna.iloc[6]
# Out:
# Cislo uctu vlastnika      1914236073/0800
# Datum zauctovani               23.08.2022
# Název protiuctu                       NaN
# IBAN                                  NaN
# BIC                                   NaN
# Protiucet                             NaN
# Bankovni kod protiuctu                NaN
# Castka                            -1800.0
# Mena                                  CZK
# Name: 7, dtype: object

# %%
df_csob.iloc[[5,10]]
# Out:
#           account no. date of posting  amount currency   deposit  \
# Index
# 6      284622580/0300      2022-07-18 -130.44      CZK  92655.54
# 11     284622580/0300      2022-07-14  -25.62      CZK  87721.24
#
#        counter-account number  counter-account bank number  \
# Index
# 6                         NaN                          NaN
# 11                        NaN                          NaN
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 6                         NaN           1178.0      405000197.0
# 11                        NaN           1178.0      405000195.0
#
#        specific symbol   marking the operation  Transaction ID  \
# Index
# 6         2.212104e+09  Debit card transaction     10476525985
# 11        2.212104e+09  Debit card transaction     10464716438
#
#                                                     note
# Index
# 6      Amount: 130,44 CZK 14.07.2022, Place: PAYPAL *...
# 11     Amount: 1 CHF 12.07.2022, Place: Shop Cern, Me...

# %%
# získání konkrétní hodnoty

df_csob.iloc[25]["amount"]
# Out:
# -300.0

# %%
# také lze získat jednotlivé řádky podle konkrétní hodnoty v indexu (pokud jsou index písmena od a do z, lze podle každého vypsat řádek) - viz. porovnání s iloc

df_sporitelna.loc[6]
# Out:
# Cislo uctu vlastnika                     1914236073/0800
# Datum zauctovani                              24.08.2022
# Název protiuctu           POTRAVINY PRAMEN LITOMERICE CZ
# IBAN                                                 NaN
# BIC                                                  NaN
# Protiucet                                            NaN
# Bankovni kod protiuctu                               0.0
# Castka                                           -241.69
# Mena                                                 CZK
# Name: 6, dtype: object

# %%
df_sporitelna.loc[6]["Název protiuctu"]
# Out:
# 'POTRAVINY PRAMEN LITOMERICE CZ'

# %%
# logické indexování pomocí boolean hodnot

df_csob.index.isin([6,30,38])
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
# pomocí boolean hodnot s indexem shodným s původním Dataframem můžeme filtrovat a získat pouze požadovaná data

df_csob[df_csob.index.isin([6, 30, 38])]
# Out:
#           account no. date of posting  amount currency    deposit  \
# Index
# 6      284622580/0300      2022-07-18 -130.44      CZK   92655.54
# 30     284622580/0300      2022-07-07 -702.40      CZK  112162.05
# 38     284622580/0300      2022-07-04 -200.00      CZK  110060.36
#
#        counter-account number  counter-account bank number  \
# Index
# 6                         NaN                          NaN
# 30                        NaN                          NaN
# 38                        NaN                          NaN
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 6                         NaN           1178.0      405000197.0
# 30                        NaN           1178.0      405000187.0
# 38                        NaN           1178.0      401000183.0
#
#        specific symbol   marking the operation  Transaction ID  \
# Index
# 6         2.212104e+09  Debit card transaction     10476525985
# 30        2.212104e+09  Debit card transaction     10443755776
# 38        2.212104e+09  Debit card transaction     10437684824
#
#                                                     note
# Index
# 6      Amount: 130,44 CZK 14.07.2022, Place: PAYPAL *...
# 30     Amount: 27,66 EUR 04.07.2022, Place: AMZN Mktp...
# 38     Amount: 200 CZK 29.06.2022, Place: MMB2417 POK...

# %%
df_csob[df_csob.index.isin([30])]["deposit"]
# Out:
# Index
# 30    112162.05
# Name: deposit, dtype: float64

# %%
# lze vyhledávat i v nečíselných hodnotách

df_csob["marking the operation"].isin(["Outgoing instant payment"])
# Out:
# Index
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
#       ...
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# Name: marking the operation, Length: 79, dtype: bool

# %%
df_csob[df_csob["marking the operation"].isin(["Outgoing instant payment"])]
# Out:
#           account no. date of posting  amount currency   deposit  \
# Index
# 2      284622580/0300      2022-07-19   -45.0      CZK  89573.93
#
#        counter-account number  counter-account bank number  \
# Index
# 2                2.008200e+09                       5500.0
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 2                         NaN              NaN              NaN
#
#        specific symbol     marking the operation  Transaction ID     note
# Index
# 2                  NaN  Outgoing instant payment     10478823066  Spotify

# %%
# získání konkrétní hodnoy podle názvu/vlastního indexu řádku a názvu sloupce

df_sporitelna.at[26, "Castka"]
# Out:
# -250.5

# %%
# podobně jako loc a iloc, lze získat i podle indexu řádku od 0 do len(dataframe)-1 a indexu sloupce podle stejného číslování od 0 do len(df.columns)-1

df_sporitelna.iat[25, -2]
# Out:
# -250.5

# %% [markdown]
# <h5>Filtrování pomocí pravdivostních výroků</h5>
#
# Podobně jako metoda .isin vracející True/False můžeme získat boolean hodnoty výroku či podmínky týkající se sloupců Dataframu a pomocí nich vyfiltrovat řádky, které podmínky nesplňují

# %%
df_csob["amount"] > 0.0
# Out:
# Index
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
#       ...
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# Name: amount, Length: 79, dtype: bool

# %%
df_csob[df_csob["amount"] > 0.0]
# Out:
#           account no. date of posting   amount currency    deposit  \
# Index
# 9      284622580/0300      2022-07-14     39.0      CZK   94115.24
# 10     284622580/0300      2022-07-14   6355.0      CZK   94076.24
# 31     284622580/0300      2022-07-07    148.0      CZK  112864.45
# 32     284622580/0300      2022-07-05   3733.0      CZK  112716.45
# 43     284622580/0300      2022-06-28  15000.0      CZK  169814.36
# 48     284622580/0300      2022-06-27   3250.0      CZK  158635.71
# 66     284622580/0300      2022-06-22   2000.0      CZK  161849.20
#
#        counter-account number  counter-account bank number  \
# Index
# 9                1.231434e+09                       3030.0
# 10               2.970417e+09                        800.0
# 31                        NaN                          NaN
# 32               1.231434e+09                       3030.0
# 43               6.144747e+07                        100.0
# 48               2.970417e+09                        800.0
# 66               6.144747e+07                        100.0
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 9              Josef VytrhlÌk              NaN              NaN
# 10            Dvo¯·kov· Lilly              0.0              NaN
# 31                        NaN           1176.0      406000186.0
# 32             Josef VytrhlÌk              NaN              NaN
# 43                KOR»¡K PETR              0.0              0.0
# 48            Dvo¯·kov· Lilly              0.0              NaN
# 66                KOR»¡K PETR              0.0              0.0
#
#        specific symbol      marking the operation  Transaction ID  \
# Index
# 9                  NaN   Incoming instant payment     10465032760
# 10                 NaN   Incoming instant payment     10464963879
# 31        2.212104e+09  Card transaction - refund     10443625098
# 32                 NaN   Incoming instant payment     10438850368
# 43        0.000000e+00           Incoming payment     10419962882
# 48                 NaN   Incoming instant payment     10418122762
# 66        0.000000e+00           Incoming payment     10404797905
#
#                                                    note
# Index
# 9                                          Eura z plesu
# 10                                                  NaN
# 31     Amount: 148 CZK 03.07.2022, Place: Alza, Prague,
# 32                       RozdÏlenÌ zbytku penÏz z plesu
# 43                              dotace zelena cestovani
# 48                                                  NaN
# 66                                              KAPESN…

# %%
df_csob[df_csob["marking the operation"] == "Incoming payment"]
# Out:
#           account no. date of posting   amount currency    deposit  \
# Index
# 43     284622580/0300      2022-06-28  15000.0      CZK  169814.36
# 66     284622580/0300      2022-06-22   2000.0      CZK  161849.20
#
#        counter-account number  counter-account bank number  \
# Index
# 43                 61447471.0                        100.0
# 66                 61447471.0                        100.0
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 43                KOR»¡K PETR              0.0              0.0
# 66                KOR»¡K PETR              0.0              0.0
#
#        specific symbol marking the operation  Transaction ID  \
# Index
# 43                 0.0      Incoming payment     10419962882
# 66                 0.0      Incoming payment     10404797905
#
#                           note
# Index
# 43     dotace zelena cestovani
# 66                     KAPESN…

# %%
# filtrovat můžeme podle více podmínek, mezi kterými rozhodne některý z logických operátorů and (&), or (|) nebo not (~), každá podmínka musí být v samostatné závorce kvůli pořadí, ve kterém je Python vyhodnocuje

df_csob[(df_csob["amount"] > 500.0) & (df_csob["marking the operation"] == "Incoming instant payment")]
# Out:
#           account no. date of posting  amount currency    deposit  \
# Index
# 10     284622580/0300      2022-07-14  6355.0      CZK   94076.24
# 32     284622580/0300      2022-07-05  3733.0      CZK  112716.45
# 48     284622580/0300      2022-06-27  3250.0      CZK  158635.71
#
#        counter-account number  counter-account bank number  \
# Index
# 10               2.970417e+09                        800.0
# 32               1.231434e+09                       3030.0
# 48               2.970417e+09                        800.0
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 10            Dvo¯·kov· Lilly              0.0              NaN
# 32             Josef VytrhlÌk              NaN              NaN
# 48            Dvo¯·kov· Lilly              0.0              NaN
#
#        specific symbol     marking the operation  Transaction ID  \
# Index
# 10                 NaN  Incoming instant payment     10464963879
# 32                 NaN  Incoming instant payment     10438850368
# 48                 NaN  Incoming instant payment     10418122762
#
#                                  note
# Index
# 10                                NaN
# 32     RozdÏlenÌ zbytku penÏz z plesu
# 48                                NaN

# %% [markdown]
# <h5>Cvičení 1: vytvořte program, který z dataframu získá informace o pohybech na účtě a pro každý den spočítá jejich celkovou bilanci, jež pak vhodně vizualizuje ve sloupcovém grafu</h5>
#
# Výdaj vyznačte červeně, příjmy zeleně
#
# Potřebná dokumentace:
# <br>
#
# <https://plotly.com/python/bar-charts/>
# <br>
#
# <https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#boolean-indexing>

# %%
# místo pro váš kód

# %%
# vzorové řešení (spusťte pro kontrolu)

def parse_vals(df, time_col, val_col):
    data_dict = {"date":[],"in":[],"out":[]}
    df[time_col] = pd.to_datetime(df[time_col], infer_datetime_format=True)
    for date in df[time_col].unique():
        temp_df = df[df[time_col] == date]
        data_dict["date"].append(date)
        data_dict["in"].append(np.sum(temp_df[temp_df[val_col] > 0.0][val_col]))
        data_dict["out"].append(np.sum(temp_df[temp_df[val_col] < 0.0][val_col]))
    return pd.DataFrame.from_dict(data_dict)

def plot_vals(df,name):
    df['date'] = df['date'].dt.strftime('%d/%m/%Y')
    return px.bar(df,y=["in","out"], x="date", barmode="group",
                  labels={"value": "CZK", "variable": "Pohyb", "date":"Datum"},
             color_discrete_map={"in": "green", "out": "red"},
             title=name)

def main():
    accounts = {
        "csob":[df_csob,"date of posting","amount","ČSOB"],
        "sporitelna":[df_sporitelna, "Datum zauctovani", "Castka", "Česká spořitelna"]
    }
    acc = input("Zadejte účet, ze kterého chcete vidět data (csob/sporitelna)")
    if not(acc in list(accounts.keys())):
        print("Chyba - špatně zadaný účet")
    else:
        df = parse_vals(accounts[acc][0], accounts[acc][1], accounts[acc][2])
        fig = plot_vals(df, accounts[acc][-1])
        fig.show()

if __name__ == "__main__":
    main()

# %% [markdown]
# <h5>Do existujících dataframů můžeme vkládat i nové sloupce a řádky</h5>

# %%
df_csob["amount"] = df_csob["amount"].astype(np.float32)

# %%
# nové sloupce, tyto sloupce pomocí bool hodnoty jednoduše indikují zda se jedná o výdaj či příjem

df_csob["Income"] = df_csob["amount"] > 0.0
df_csob["Expense"] = df_csob["amount"] < 0.0
df_csob
# Out:
#           account no. date of posting       amount currency    deposit  \
# Index
# 1      284622580/0300      2022-07-19  -791.150024      CZK   88782.78
# 2      284622580/0300      2022-07-19   -45.000000      CZK   89573.93
# 3      284622580/0300      2022-07-18  -475.929993      CZK   89618.93
# 4      284622580/0300      2022-07-18  -225.440002      CZK   90094.86
# 5      284622580/0300      2022-07-18 -2335.239990      CZK   90320.30
# ...               ...             ...          ...      ...        ...
# 75     284622580/0300      2022-06-20  -689.989990      CZK  162730.48
# 76     284622580/0300      2022-06-20  -290.519989      CZK  163420.47
# 77     284622580/0300      2022-06-20  -189.919998      CZK  163710.99
# 78     284622580/0300      2022-06-20   -68.849998      CZK  163900.91
# 79     284622580/0300      2022-06-20 -1044.560059      CZK  163969.76
#
#        counter-account number  counter-account bank number  \
# Index
# 1                         NaN                          NaN
# 2                2.008200e+09                       5500.0
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# 5                         NaN                          NaN
# ...                       ...                          ...
# 75                        NaN                          NaN
# 76                        NaN                          NaN
# 77                        NaN                          NaN
# 78                        NaN                          NaN
# 79                        NaN                          NaN
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 1                         NaN           1178.0      405000199.0
# 2                         NaN              NaN              NaN
# 3                         NaN           1178.0      405000198.0
# 4                         NaN           1178.0      405000197.0
# 5                         NaN           1178.0      405000197.0
# ...                       ...              ...              ...
# 75                        NaN           1178.0      405000170.0
# 76                        NaN           1178.0      405000170.0
# 77                        NaN           1178.0      405000169.0
# 78                        NaN           1178.0      405000169.0
# 79                        NaN           1178.0      405000169.0
#
#        specific symbol     marking the operation  Transaction ID  \
# Index
# 1         2.212104e+09    Debit card transaction     10479404244
# 2                  NaN  Outgoing instant payment     10478823066
# 3         2.212104e+09    Debit card transaction     10476817120
# 4         2.212104e+09    Debit card transaction     10476525982
# 5         2.212104e+09    Debit card transaction     10476525984
# ...                ...                       ...             ...
# 75        2.212104e+09    Debit card transaction     10400956338
# 76        2.212104e+09    Debit card transaction     10400956344
# 77        2.212104e+09    Debit card transaction     10400813269
# 78        2.212104e+09    Debit card transaction     10400813274
# 79        2.212104e+09    Debit card transaction     10400813278
#
#                                                     note  Income  Expense
# Index
# 1      Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...   False     True
# 2                                                Spotify   False     True
# 3      Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...   False     True
# 4      Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...   False     True
# 5      Amount: 92 CHF 14.07.2022, Place: Restaurant H...   False     True
# ...                                                  ...     ...      ...
# 75     Amount: 285 NOK 17.06.2022, Place: VULKANFISK ...   False     True
# 76     Amount: 120 NOK 17.06.2022, Place: ONEPARK VUL...   False     True
# 77     Amount: 80 SEK 16.06.2022, Place: CAFEVA AB, B...   False     True
# 78     Amount: 29 SEK 16.06.2022, Place: KAWAII.SE GB...   False     True
# 79     Amount: 440 SEK 16.06.2022, Place: STROMMA PC ...   False     True
#
# [79 rows x 16 columns]

# %%
# nový sloupec či sloupce lze k dataframu připojit pomocí metody join

new_col = pd.Series(["Expense" if x else "Income" for x in df_csob["amount"] < 0.0], name="Income/Expense")
df_csob.join(new_col)
# Out:
#           account no. date of posting       amount currency    deposit  \
# Index
# 1      284622580/0300      2022-07-19  -791.150024      CZK   88782.78
# 2      284622580/0300      2022-07-19   -45.000000      CZK   89573.93
# 3      284622580/0300      2022-07-18  -475.929993      CZK   89618.93
# 4      284622580/0300      2022-07-18  -225.440002      CZK   90094.86
# 5      284622580/0300      2022-07-18 -2335.239990      CZK   90320.30
# ...               ...             ...          ...      ...        ...
# 75     284622580/0300      2022-06-20  -689.989990      CZK  162730.48
# 76     284622580/0300      2022-06-20  -290.519989      CZK  163420.47
# 77     284622580/0300      2022-06-20  -189.919998      CZK  163710.99
# 78     284622580/0300      2022-06-20   -68.849998      CZK  163900.91
# 79     284622580/0300      2022-06-20 -1044.560059      CZK  163969.76
#
#        counter-account number  counter-account bank number  \
# Index
# 1                         NaN                          NaN
# 2                2.008200e+09                       5500.0
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# 5                         NaN                          NaN
# ...                       ...                          ...
# 75                        NaN                          NaN
# 76                        NaN                          NaN
# 77                        NaN                          NaN
# 78                        NaN                          NaN
# 79                        NaN                          NaN
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 1                         NaN           1178.0      405000199.0
# 2                         NaN              NaN              NaN
# 3                         NaN           1178.0      405000198.0
# 4                         NaN           1178.0      405000197.0
# 5                         NaN           1178.0      405000197.0
# ...                       ...              ...              ...
# 75                        NaN           1178.0      405000170.0
# 76                        NaN           1178.0      405000170.0
# 77                        NaN           1178.0      405000169.0
# 78                        NaN           1178.0      405000169.0
# 79                        NaN           1178.0      405000169.0
#
#        specific symbol     marking the operation  Transaction ID  \
# Index
# 1         2.212104e+09    Debit card transaction     10479404244
# 2                  NaN  Outgoing instant payment     10478823066
# 3         2.212104e+09    Debit card transaction     10476817120
# 4         2.212104e+09    Debit card transaction     10476525982
# 5         2.212104e+09    Debit card transaction     10476525984
# ...                ...                       ...             ...
# 75        2.212104e+09    Debit card transaction     10400956338
# 76        2.212104e+09    Debit card transaction     10400956344
# 77        2.212104e+09    Debit card transaction     10400813269
# 78        2.212104e+09    Debit card transaction     10400813274
# 79        2.212104e+09    Debit card transaction     10400813278
#
#                                                     note  Income  Expense  \
# Index
# 1      Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...   False     True
# 2                                                Spotify   False     True
# 3      Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...   False     True
# 4      Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...   False     True
# 5      Amount: 92 CHF 14.07.2022, Place: Restaurant H...   False     True
# ...                                                  ...     ...      ...
# 75     Amount: 285 NOK 17.06.2022, Place: VULKANFISK ...   False     True
# 76     Amount: 120 NOK 17.06.2022, Place: ONEPARK VUL...   False     True
# 77     Amount: 80 SEK 16.06.2022, Place: CAFEVA AB, B...   False     True
# 78     Amount: 29 SEK 16.06.2022, Place: KAWAII.SE GB...   False     True
# 79     Amount: 440 SEK 16.06.2022, Place: STROMMA PC ...   False     True
#
#       Income/Expense
# Index
# 1            Expense
# 2            Expense
# 3            Expense
# 4            Expense
# 5            Expense
# ...              ...
# 75           Expense
# 76           Expense
# 77           Expense
# 78           Expense
# 79               NaN
#
# [79 rows x 17 columns]

# %%
# odstranění sloupců

df_csob.drop(["Income","Expense"],axis=1, inplace=True)
df_csob
# Out:
#           account no. date of posting       amount currency    deposit  \
# Index
# 1      284622580/0300      2022-07-19  -791.150024      CZK   88782.78
# 2      284622580/0300      2022-07-19   -45.000000      CZK   89573.93
# 3      284622580/0300      2022-07-18  -475.929993      CZK   89618.93
# 4      284622580/0300      2022-07-18  -225.440002      CZK   90094.86
# 5      284622580/0300      2022-07-18 -2335.239990      CZK   90320.30
# ...               ...             ...          ...      ...        ...
# 75     284622580/0300      2022-06-20  -689.989990      CZK  162730.48
# 76     284622580/0300      2022-06-20  -290.519989      CZK  163420.47
# 77     284622580/0300      2022-06-20  -189.919998      CZK  163710.99
# 78     284622580/0300      2022-06-20   -68.849998      CZK  163900.91
# 79     284622580/0300      2022-06-20 -1044.560059      CZK  163969.76
#
#        counter-account number  counter-account bank number  \
# Index
# 1                         NaN                          NaN
# 2                2.008200e+09                       5500.0
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# 5                         NaN                          NaN
# ...                       ...                          ...
# 75                        NaN                          NaN
# 76                        NaN                          NaN
# 77                        NaN                          NaN
# 78                        NaN                          NaN
# 79                        NaN                          NaN
#
#       name of counter-account  constant symbol  variable symbol  \
# Index
# 1                         NaN           1178.0      405000199.0
# 2                         NaN              NaN              NaN
# 3                         NaN           1178.0      405000198.0
# 4                         NaN           1178.0      405000197.0
# 5                         NaN           1178.0      405000197.0
# ...                       ...              ...              ...
# 75                        NaN           1178.0      405000170.0
# 76                        NaN           1178.0      405000170.0
# 77                        NaN           1178.0      405000169.0
# 78                        NaN           1178.0      405000169.0
# 79                        NaN           1178.0      405000169.0
#
#        specific symbol     marking the operation  Transaction ID  \
# Index
# 1         2.212104e+09    Debit card transaction     10479404244
# 2                  NaN  Outgoing instant payment     10478823066
# 3         2.212104e+09    Debit card transaction     10476817120
# 4         2.212104e+09    Debit card transaction     10476525982
# 5         2.212104e+09    Debit card transaction     10476525984
# ...                ...                       ...             ...
# 75        2.212104e+09    Debit card transaction     10400956338
# 76        2.212104e+09    Debit card transaction     10400956344
# 77        2.212104e+09    Debit card transaction     10400813269
# 78        2.212104e+09    Debit card transaction     10400813274
# 79        2.212104e+09    Debit card transaction     10400813278
#
#                                                     note
# Index
# 1      Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...
# 2                                                Spotify
# 3      Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...
# 4      Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...
# 5      Amount: 92 CHF 14.07.2022, Place: Restaurant H...
# ...                                                  ...
# 75     Amount: 285 NOK 17.06.2022, Place: VULKANFISK ...
# 76     Amount: 120 NOK 17.06.2022, Place: ONEPARK VUL...
# 77     Amount: 80 SEK 16.06.2022, Place: CAFEVA AB, B...
# 78     Amount: 29 SEK 16.06.2022, Place: KAWAII.SE GB...
# 79     Amount: 440 SEK 16.06.2022, Place: STROMMA PC ...
#
# [79 rows x 14 columns]

# %%
# nové řádky, provedeno formou konkatování ("slepení") dvou dataframů - původního dataframu a nového řádku

new_line = {"account no.": ["284622580/0300"], "date of posting":["2022-09-01"],"amount":["8000"], "currency":["USD"]}
new_line = pd.DataFrame(new_line)

df_csob = pd.concat([df_csob, new_line], ignore_index=True)
df_csob
# Out:
#        account no.      date of posting       amount currency    deposit  \
# 0   284622580/0300  2022-07-19 00:00:00  -791.150024      CZK   88782.78
# 1   284622580/0300  2022-07-19 00:00:00        -45.0      CZK   89573.93
# 2   284622580/0300  2022-07-18 00:00:00  -475.929993      CZK   89618.93
# 3   284622580/0300  2022-07-18 00:00:00  -225.440002      CZK   90094.86
# 4   284622580/0300  2022-07-18 00:00:00  -2335.23999      CZK   90320.30
# ..             ...                  ...          ...      ...        ...
# 75  284622580/0300  2022-06-20 00:00:00  -290.519989      CZK  163420.47
# 76  284622580/0300  2022-06-20 00:00:00  -189.919998      CZK  163710.99
# 77  284622580/0300  2022-06-20 00:00:00   -68.849998      CZK  163900.91
# 78  284622580/0300  2022-06-20 00:00:00 -1044.560059      CZK  163969.76
# 79  284622580/0300           2022-09-01         8000      USD        NaN
#
#     counter-account number  counter-account bank number  \
# 0                      NaN                          NaN
# 1             2.008200e+09                       5500.0
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# ..                     ...                          ...
# 75                     NaN                          NaN
# 76                     NaN                          NaN
# 77                     NaN                          NaN
# 78                     NaN                          NaN
# 79                     NaN                          NaN
#
#    name of counter-account  constant symbol  variable symbol  specific symbol  \
# 0                      NaN           1178.0      405000199.0     2.212104e+09
# 1                      NaN              NaN              NaN              NaN
# 2                      NaN           1178.0      405000198.0     2.212104e+09
# 3                      NaN           1178.0      405000197.0     2.212104e+09
# 4                      NaN           1178.0      405000197.0     2.212104e+09
# ..                     ...              ...              ...              ...
# 75                     NaN           1178.0      405000170.0     2.212104e+09
# 76                     NaN           1178.0      405000169.0     2.212104e+09
# 77                     NaN           1178.0      405000169.0     2.212104e+09
# 78                     NaN           1178.0      405000169.0     2.212104e+09
# 79                     NaN              NaN              NaN              NaN
#
#        marking the operation  Transaction ID  \
# 0     Debit card transaction    1.047940e+10
# 1   Outgoing instant payment    1.047882e+10
# 2     Debit card transaction    1.047682e+10
# 3     Debit card transaction    1.047653e+10
# 4     Debit card transaction    1.047653e+10
# ..                       ...             ...
# 75    Debit card transaction    1.040096e+10
# 76    Debit card transaction    1.040081e+10
# 77    Debit card transaction    1.040081e+10
# 78    Debit card transaction    1.040081e+10
# 79                       NaN             NaN
#
#                                                  note
# 0   Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...
# 1                                             Spotify
# 2   Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...
# 3   Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...
# 4   Amount: 92 CHF 14.07.2022, Place: Restaurant H...
# ..                                                ...
# 75  Amount: 120 NOK 17.06.2022, Place: ONEPARK VUL...
# 76  Amount: 80 SEK 16.06.2022, Place: CAFEVA AB, B...
# 77  Amount: 29 SEK 16.06.2022, Place: KAWAII.SE GB...
# 78  Amount: 440 SEK 16.06.2022, Place: STROMMA PC ...
# 79                                                NaN
#
# [80 rows x 14 columns]

# %%
# odstranění řádku (stejnou metodou jako u sloupců)

df_csob = df_csob.drop(79, axis=0)
df_csob
# Out:
#        account no.      date of posting       amount currency    deposit  \
# 0   284622580/0300  2022-07-19 00:00:00  -791.150024      CZK   88782.78
# 1   284622580/0300  2022-07-19 00:00:00        -45.0      CZK   89573.93
# 2   284622580/0300  2022-07-18 00:00:00  -475.929993      CZK   89618.93
# 3   284622580/0300  2022-07-18 00:00:00  -225.440002      CZK   90094.86
# 4   284622580/0300  2022-07-18 00:00:00  -2335.23999      CZK   90320.30
# ..             ...                  ...          ...      ...        ...
# 74  284622580/0300  2022-06-20 00:00:00   -689.98999      CZK  162730.48
# 75  284622580/0300  2022-06-20 00:00:00  -290.519989      CZK  163420.47
# 76  284622580/0300  2022-06-20 00:00:00  -189.919998      CZK  163710.99
# 77  284622580/0300  2022-06-20 00:00:00   -68.849998      CZK  163900.91
# 78  284622580/0300  2022-06-20 00:00:00 -1044.560059      CZK  163969.76
#
#     counter-account number  counter-account bank number  \
# 0                      NaN                          NaN
# 1             2.008200e+09                       5500.0
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# ..                     ...                          ...
# 74                     NaN                          NaN
# 75                     NaN                          NaN
# 76                     NaN                          NaN
# 77                     NaN                          NaN
# 78                     NaN                          NaN
#
#    name of counter-account  constant symbol  variable symbol  specific symbol  \
# 0                      NaN           1178.0      405000199.0     2.212104e+09
# 1                      NaN              NaN              NaN              NaN
# 2                      NaN           1178.0      405000198.0     2.212104e+09
# 3                      NaN           1178.0      405000197.0     2.212104e+09
# 4                      NaN           1178.0      405000197.0     2.212104e+09
# ..                     ...              ...              ...              ...
# 74                     NaN           1178.0      405000170.0     2.212104e+09
# 75                     NaN           1178.0      405000170.0     2.212104e+09
# 76                     NaN           1178.0      405000169.0     2.212104e+09
# 77                     NaN           1178.0      405000169.0     2.212104e+09
# 78                     NaN           1178.0      405000169.0     2.212104e+09
#
#        marking the operation  Transaction ID  \
# 0     Debit card transaction    1.047940e+10
# 1   Outgoing instant payment    1.047882e+10
# 2     Debit card transaction    1.047682e+10
# 3     Debit card transaction    1.047653e+10
# 4     Debit card transaction    1.047653e+10
# ..                       ...             ...
# 74    Debit card transaction    1.040096e+10
# 75    Debit card transaction    1.040096e+10
# 76    Debit card transaction    1.040081e+10
# 77    Debit card transaction    1.040081e+10
# 78    Debit card transaction    1.040081e+10
#
#                                                  note
# 0   Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...
# 1                                             Spotify
# 2   Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...
# 3   Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...
# 4   Amount: 92 CHF 14.07.2022, Place: Restaurant H...
# ..                                                ...
# 74  Amount: 285 NOK 17.06.2022, Place: VULKANFISK ...
# 75  Amount: 120 NOK 17.06.2022, Place: ONEPARK VUL...
# 76  Amount: 80 SEK 16.06.2022, Place: CAFEVA AB, B...
# 77  Amount: 29 SEK 16.06.2022, Place: KAWAII.SE GB...
# 78  Amount: 440 SEK 16.06.2022, Place: STROMMA PC ...
#
# [79 rows x 14 columns]

# %% [markdown]
# <h5>Slučování a připojování dataframů</h5>
#
# Modul pandas nabízí několik způsobů, jak dataframy spojit či sloučit do jednoho, a to na základě indexů či sloupců

# %%
# načteme si druhý výpis z účtu ČSOB

df_csob2 = pd.read_excel("dataset/csob2.xls")
df_csob2
# Out:
#        account no. date of posting  amount currency    deposit  \
# 0   284622580/0300      2022-09-14    -599      CZK  124131.41
# 1   284622580/0300      2022-09-14    -399      CZK  124730.41
# 2   284622580/0300      2022-09-09   -6700      CZK  125129.41
# 3   284622580/0300      2022-09-09     -40      CZK  131829.41
# 4   284622580/0300      2022-09-09    -300      CZK  131869.41
# 5   284622580/0300      2022-09-08    -100      CZK  132169.41
# 6   284622580/0300      2022-09-08    -220      CZK  132269.41
# 7   284622580/0300      2022-09-08   -3000      CZK  132489.41
# 8   284622580/0300      2022-09-08     -85      CZK  135489.41
# 9   284622580/0300      2022-09-07     -60      CZK  135574.41
# 10  284622580/0300      2022-09-05    -200      CZK  135634.41
# 11  284622580/0300      2022-09-05   -1280      CZK  135834.41
# 12  284622580/0300      2022-09-05    -280      CZK  137114.41
# 13  284622580/0300      2022-09-05     -30      CZK  137394.41
# 14  284622580/0300      2022-09-05     -30      CZK  137424.41
# 15  284622580/0300      2022-09-05   15000      CZK  137454.41
# 16  284622580/0300      2022-09-02     -15      CZK  122454.41
# 17  284622580/0300      2022-09-02     -30      CZK  122469.41
# 18  284622580/0300      2022-09-02     -30      CZK  122499.41
# 19  284622580/0300      2022-09-02     -30      CZK  122529.41
# 20  284622580/0300      2022-09-02     -30      CZK  122559.41
# 21  284622580/0300      2022-09-01    -165      CZK  122589.41
# 22  284622580/0300      2022-09-01     -30      CZK  122754.41
# 23  284622580/0300      2022-09-01     -30      CZK  122784.41
# 24  284622580/0300      2022-09-01    -461      CZK  122814.41
#
#     counter-account number  counter-account bank number  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# 5             1.431288e+09                        800.0
# 6                      NaN                          NaN
# 7                      NaN                          NaN
# 8                      NaN                          NaN
# 9                      NaN                          NaN
# 10                     NaN                          NaN
# 11                     NaN                          NaN
# 12                     NaN                          NaN
# 13                     NaN                          NaN
# 14                     NaN                          NaN
# 15            1.914236e+09                        800.0
# 16                     NaN                          NaN
# 17                     NaN                          NaN
# 18                     NaN                          NaN
# 19                     NaN                          NaN
# 20                     NaN                          NaN
# 21                     NaN                          NaN
# 22                     NaN                          NaN
# 23                     NaN                          NaN
# 24                     NaN                          NaN
#
#    name of counter-account  constant symbol  variable symbol  specific symbol  \
# 0                      NaN             1178      405000257.0     2.212104e+09
# 1                      NaN             1178      405000256.0     2.212104e+09
# 2                      NaN             1178      401000251.0     2.212104e+09
# 3                      NaN             6898      497000251.0     2.212104e+09
# 4                      NaN             9988      306072844.0              NaN
# 5                      NaN                0              NaN              NaN
# 6                      NaN             1178      405000251.0     2.212104e+09
# 7                      NaN             1178      405000251.0     2.212104e+09
# 8                      NaN             1178      405000251.0     2.212104e+09
# 9                      NaN             1178      405000249.0     2.212104e+09
# 10                     NaN             1178      405000246.0     2.212104e+09
# 11                     NaN             1178      405000246.0     2.212104e+09
# 12                     NaN             1178      405000245.0     2.212104e+09
# 13                     NaN             1178      405000245.0     2.212104e+09
# 14                     NaN             1178      405000245.0     2.212104e+09
# 15         Korčáková Jitka                0              NaN              NaN
# 16                     NaN             1178      405000245.0     2.212104e+09
# 17                     NaN             1178      405000245.0     2.212104e+09
# 18                     NaN             1178      405000245.0     2.212104e+09
# 19                     NaN             1178      405000245.0     2.212104e+09
# 20                     NaN             1178      405000245.0     2.212104e+09
# 21                     NaN             1178      405000243.0     2.212104e+09
# 22                     NaN             1178      405000243.0     2.212104e+09
# 23                     NaN             1178      405000243.0     2.212104e+09
# 24                     NaN             1178      405000243.0     2.212104e+09
#
#        marking the operation  Transaction ID  \
# 0     Debit card transaction     10630853946
# 1     Debit card transaction     10630653559
# 2     Debit card transaction     10616143852
# 3           Payment card fee     10616143856
# 4                ČSOB Drobné     10613590750
# 5   Outgoing instant payment     10613379393
# 6     Debit card transaction     10612934315
# 7     Debit card transaction     10612934318
# 8     Debit card transaction     10612934319
# 9     Debit card transaction     10609956389
# 10    Debit card transaction     10604688744
# 11    Debit card transaction     10604688750
# 12    Debit card transaction     10604322740
# 13    Debit card transaction     10604322747
# 14    Debit card transaction     10604322751
# 15          Incoming payment     10600547183
# 16    Debit card transaction     10598961232
# 17    Debit card transaction     10598961238
# 18    Debit card transaction     10598961239
# 19    Debit card transaction     10598961240
# 20    Debit card transaction     10598961241
# 21    Debit card transaction     10596132089
# 22    Debit card transaction     10596132091
# 23    Debit card transaction     10596132093
# 24    Debit card transaction     10596132097
#
#                                                  note
# 0   Amount: 599 CZK 13.09.2022, Place: Vodafone Cz...
# 1   Amount: 399 CZK 12.09.2022, Place: bezrealitky...
# 2   Amount: 6700 CZK 07.09.2022, Place: CS, MASARY...
# 3   Místo: Transakcni poplatek, Částka: 0 CZK 07.0...
# 4                                      ČSOB Bohatství
# 5   Dobrý den, posílám částku za prací, prášek, mo...
# 6   Amount: 220 CZK 06.09.2022, Place: INDICKA RES...
# 7   Amount: 3000 CZK 06.09.2022, Place: MATRACOVE ...
# 8   Amount: 85 CZK 06.09.2022, Place: GOLDEN EGG, ...
# 9   Amount: 60 CZK 05.09.2022, Place: www.cd.cz/es...
# 10  Amount: 200 CZK 01.09.2022, Place: HOIAN, PRAH...
# 11  Amount: 1280 CZK 02.09.2022, Place: Operator I...
# 12  Amount: 280 CZK 30.08.2022, Place: MATLOK, PRA...
# 13  Amount: 30 CZK 01.09.2022, Place: Operator ICT...
# 14  Amount: 30 CZK 01.09.2022, Place: Operator ICT...
# 15                                                NaN
# 16  Amount: 15 CZK 31.08.2022, Place: IKEA ZLICIN ...
# 17  Amount: 30 CZK 31.08.2022, Place: Operator ICT...
# 18  Amount: 30 CZK 31.08.2022, Place: Operator ICT...
# 19  Amount: 30 CZK 31.08.2022, Place: Operator ICT...
# 20  Amount: 30 CZK 31.08.2022, Place: Operator ICT...
# 21  Amount: 165 CZK 30.08.2022, Place: RESTAURACE ...
# 22  Amount: 30 CZK 30.08.2022, Place: Operator ICT...
# 23  Amount: 30 CZK 30.08.2022, Place: Operator ICT...
# 24  Amount: 461 CZK 30.08.2022, Place: DM DROGERIE...

# %%
# připojení dataframů za sebe do jedné delší tabulky

df_csob_complete = pd.concat([df_csob,df_csob2], axis=0, ignore_index=True)
df_csob_complete
# Out:
#         account no.      date of posting      amount currency    deposit  \
# 0    284622580/0300  2022-07-19 00:00:00 -791.150024      CZK   88782.78
# 1    284622580/0300  2022-07-19 00:00:00       -45.0      CZK   89573.93
# 2    284622580/0300  2022-07-18 00:00:00 -475.929993      CZK   89618.93
# 3    284622580/0300  2022-07-18 00:00:00 -225.440002      CZK   90094.86
# 4    284622580/0300  2022-07-18 00:00:00 -2335.23999      CZK   90320.30
# ..              ...                  ...         ...      ...        ...
# 99   284622580/0300  2022-09-02 00:00:00         -30      CZK  122559.41
# 100  284622580/0300  2022-09-01 00:00:00        -165      CZK  122589.41
# 101  284622580/0300  2022-09-01 00:00:00         -30      CZK  122754.41
# 102  284622580/0300  2022-09-01 00:00:00         -30      CZK  122784.41
# 103  284622580/0300  2022-09-01 00:00:00        -461      CZK  122814.41
#
#      counter-account number  counter-account bank number  \
# 0                       NaN                          NaN
# 1              2.008200e+09                       5500.0
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ..                      ...                          ...
# 99                      NaN                          NaN
# 100                     NaN                          NaN
# 101                     NaN                          NaN
# 102                     NaN                          NaN
# 103                     NaN                          NaN
#
#     name of counter-account  constant symbol  variable symbol  \
# 0                       NaN           1178.0      405000199.0
# 1                       NaN              NaN              NaN
# 2                       NaN           1178.0      405000198.0
# 3                       NaN           1178.0      405000197.0
# 4                       NaN           1178.0      405000197.0
# ..                      ...              ...              ...
# 99                      NaN           1178.0      405000245.0
# 100                     NaN           1178.0      405000243.0
# 101                     NaN           1178.0      405000243.0
# 102                     NaN           1178.0      405000243.0
# 103                     NaN           1178.0      405000243.0
#
#      specific symbol     marking the operation  Transaction ID  \
# 0       2.212104e+09    Debit card transaction    1.047940e+10
# 1                NaN  Outgoing instant payment    1.047882e+10
# 2       2.212104e+09    Debit card transaction    1.047682e+10
# 3       2.212104e+09    Debit card transaction    1.047653e+10
# 4       2.212104e+09    Debit card transaction    1.047653e+10
# ..               ...                       ...             ...
# 99      2.212104e+09    Debit card transaction    1.059896e+10
# 100     2.212104e+09    Debit card transaction    1.059613e+10
# 101     2.212104e+09    Debit card transaction    1.059613e+10
# 102     2.212104e+09    Debit card transaction    1.059613e+10
# 103     2.212104e+09    Debit card transaction    1.059613e+10
#
#                                                   note
# 0    Amount: 31,5 EUR 17.07.2022, Place: Zeppelin M...
# 1                                              Spotify
# 2    Amount: 19 USD 15.07.2022, Place: PAYPAL *HOLA...
# 3    Amount: 9 USD 15.07.2022, Place: AIRALO, SINGA...
# 4    Amount: 92 CHF 14.07.2022, Place: Restaurant H...
# ..                                                 ...
# 99   Amount: 30 CZK 31.08.2022, Place: Operator ICT...
# 100  Amount: 165 CZK 30.08.2022, Place: RESTAURACE ...
# 101  Amount: 30 CZK 30.08.2022, Place: Operator ICT...
# 102  Amount: 30 CZK 30.08.2022, Place: Operator ICT...
# 103  Amount: 461 CZK 30.08.2022, Place: DM DROGERIE...
#
# [104 rows x 14 columns]

# %%
# stejný výsledek pomocí metody merge vycházející z konvencí databázových systémů

df_csob_complete = df_csob.merge(df_csob2, how="outer")
df_csob_complete
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/davidkorcak/Documents/kurz-python-1/python_projekty/bank_account_analysis/analysis_week1.ipynb Cell 51 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/davidkorcak/Documents/kurz-python-1/python_projekty/bank_account_analysis/analysis_week1.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> # stejný výsledek pomocí metody merge vycházející z konvencí databázových systémů
# ----> <a href='vscode-notebook-cell:/Users/davidkorcak/Documents/kurz-python-1/python_projekty/bank_account_analysis/analysis_week1.ipynb#Y101sZmlsZQ%3D%3D?line=2'>3</a> df_csob_complete = df_csob.merge(df_csob2, how="outer")
#       <a href='vscode-notebook-cell:/Users/davidkorcak/Documents/kurz-python-1/python_projekty/bank_account_analysis/analysis_week1.ipynb#Y101sZmlsZQ%3D%3D?line=3'>4</a> df_csob_complete
#
# File ~/.venv/lib/python3.10/site-packages/pandas/core/frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
#    9356         copy=copy,
#    9357         indicator=indicator,
#    9358         validate=validate,
#    9359     )
#
# File ~/.venv/lib/python3.10/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~/.venv/lib/python3.10/site-packages/pandas/core/reshape/merge.py:704, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
#     700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
# --> 704 self._maybe_coerce_merge_keys()
#     706 # If argument passed to validate,
#     707 # check if columns specified as unique
#     708 # are in fact unique.
#     709 if validate is not None:
#
# File ~/.venv/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1263, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1261     raise ValueError(msg)
#    1262 elif not needs_i8_conversion(lk.dtype) and needs_i8_conversion(rk.dtype):
# -> 1263     raise ValueError(msg)
#    1264 elif is_datetime64tz_dtype(lk.dtype) and not is_datetime64tz_dtype(
#    1265     rk.dtype
#    1266 ):
#    1267     raise ValueError(msg)
#
# ValueError: You are trying to merge on object and datetime64[ns] columns. If you wish to proceed you should use pd.concat

# %%
# spojování dataframů na ose x (ose 1) - přidávání sloupců pomocí metody join

new_df = pd.DataFrame({"Income/Expense":["Expense" if x else "Income" for x in df_csob2["amount"] < 0.0], "Custom code":[1 if x else 0 for x in df_csob2["deposit"] > 100000.0]},columns=["Income/Expense","Custom code"])
df_csob2.join(new_df)
# Out:
# Running cells with '/opt/homebrew/bin/python3' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
